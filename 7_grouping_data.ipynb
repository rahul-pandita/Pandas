# %%
import pandas as pd

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="ResponseId")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col="qname")

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head(10)
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 1           I agree                                      None of these
# 2           I agree                     I am a developer by profession
# 3           I agree                     I am a developer by profession
# 4           I agree                     I am a developer by profession
# 5           I agree                     I am a developer by profession
# 6           I agree                     I am a developer by profession
# 7           I agree                     I am a developer by profession
# 8           I agree                     I am a developer by profession
# 9           I agree  I am not primarily a developer, but I write co...
# 10          I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 1           18-24 years old
# 2           25-34 years old
# 3           45-54 years old
# 4           25-34 years old
# ...

# %%
###AGGREGATION

# %%
df["CompTotal"].head(15)
# Out:
# ResponseId
# 1           NaN
# 2      285000.0
# 3      250000.0
# 4      156000.0
# 5     1320000.0
# 6       78000.0
# 7      135000.0
# 8       80000.0
# 9       60000.0
# 10          NaN
# 11          NaN
# 12     118000.0
# 13      75000.0
# 14     150000.0
# 15     175000.0
# Name: CompTotal, dtype: float64

# %%
df["CompTotal"].median()
# Out:
# 115000.0

# %%
df.median(numeric_only=True)
# Out:
# CompTotal              115000.0
# WorkExp                     9.0
# ConvertedCompYearly     74963.0
# dtype: float64

# %%
df.describe()
# Out:
#           CompTotal       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df["ConvertedCompYearly"].count()
# Out:
# 48019

# %%
df["DevType"].value_counts()
# Out:
# DevType
# Developer, full-stack                            25735
# Developer, back-end                              13745
# Developer, front-end                              5071
# Developer, desktop or enterprise applications     3904
# Other (please specify):                           3080
# Developer, mobile                                 2597
# Engineering manager                               2033
# Student                                           1996
# Developer, embedded applications or devices       1845
# Data scientist or machine learning specialist     1588
# DevOps specialist                                 1387
# Academic researcher                               1354
# Research & Development role                       1353
# Senior Executive (C-Suite, VP, etc.)              1332
# Engineer, data                                    1248
# Cloud infrastructure engineer                     1036
# Developer, game or graphics                        866
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# ...

# %%
df["Age"].value_counts(normalize=True)
# Out:
# Age
# 25-34 years old       0.372791
# 35-44 years old       0.230221
# 18-24 years old       0.201056
# 45-54 years old       0.093447
# Under 18 years old    0.046286
# 55-64 years old       0.038034
# 65 years or older     0.013130
# Prefer not to say     0.005035
# Name: proportion, dtype: float64

# %%
schema_df.loc["ToolsTechHaveWorkedWith"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ToolsTechHaveWorkedWith'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ...

# %%
schema_df
# Out:
#                          qid  \
# qname
# S0                     QID16
# MetaInfo               QID12
# Q310                  QID310
# Q120                  QID312
# S1                      QID1
# MainBranch              QID2
# Age                   QID127
# Employment            QID296
# RemoteWork            QID308
# CodingActivities      QID297
# S2                    QID190
# EdLevel                QID25
# LearnCode             QID276
# LearnCodeOnline       QID281
# LearnCodeCoursesCert  QID306
# YearsCode              QID32
# YearsCodePro           QID34
# DevType                QID31
# OrgSize                QID29
# PurchaseInfluence     QID278
# TechList              QID322
# BuyNewTool            QID279
# Country                 QID6
# Currency               QID50
# CompTotal              QID51
# S3                     QID61
# Language              QID233
# Database              QID262
# Platform              QID263
# Webframe              QID264
# ...

# %%
df.columns
# Out:
# Index(['Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'AISearchHaveWorkedWith',
# ...

# %%
schema_df.loc["Industry"]
# Out:
# qid                                                  QID326
# question      What industry is the company you work for in?
# force_resp                                            False
# type                                                     MC
# selector                                               SAVR
# Name: Industry, dtype: object

# %%
df["Industry"].value_counts()
# Out:
# Industry
# Information Services, IT, Software Development, or other Technology    18159
# Financial Services                                                      4421
# Other                                                                   4011
# Manufacturing, Transportation, or Supply Chain                          2607
# Healthcare                                                              2216
# Retail and Consumer Services                                            1955
# Higher Education                                                        1242
# Advertising Services                                                     786
# Insurance                                                                707
# Oil & Gas                                                                276
# Legal Services                                                           210
# Wholesale                                                                184
# Name: count, dtype: int64

# %%
schema_df.loc["NEWCollabTools", "question"]
# Out:
# 'Which <strong>development environments</strong> did you use regularly over the past year, and which do you want to work with over the next year? Please check all that apply.'

# %%
df["NEWCollabToolsHaveWorkedWith"].value_counts()
# Out:
# NEWCollabToolsHaveWorkedWith
# Visual Studio Code                                                                                                                                  8754
# Visual Studio;Visual Studio Code                                                                                                                    3430
# Notepad++;Visual Studio;Visual Studio Code                                                                                                          2167
# IntelliJ IDEA;Visual Studio Code                                                                                                                    1654
# Vim;Visual Studio Code                                                                                                                              1602
#                                                                                                                                                     ...
# ...

# %%
# groupby function - splitting an object, applying a function,
# combining those results

# %%
df["Country"].value_counts()
# Out:
# Country
# United States of America                                18647
# Germany                                                  7328
# India                                                    5625
# United Kingdom of Great Britain and Northern Ireland     5552
# Canada                                                   3507
#                                                         ...
# Saint Kitts and Nevis                                       1
# Marshall Islands                                            1
# Samoa                                                       1
# Central African Republic                                    1
# San Marino                                                  1
# Name: count, Length: 185, dtype: int64

# %%
country_goup = df.groupby(["Country"])
# country_goup = df.groupby(("Country"))

# %%
country_goup.get_group("India")
# Out:
# C:\Users\Rahul\AppData\Local\Temp\ipykernel_1648\1040508034.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   country_goup.get_group("India")
#                Q120                                         MainBranch  \
# ResponseId
# 10          I agree                     I am a developer by profession
# 67          I agree                     I am a developer by profession
# 79          I agree                     I am a developer by profession
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# ...

# %%
filt = df["Country"] == "India"

# %%
df.loc[filt]
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 10          I agree                     I am a developer by profession
# 67          I agree                     I am a developer by profession
# 79          I agree                     I am a developer by profession
# 83          I agree                     I am a developer by profession
# 86          I agree                     I am a developer by profession
# ...             ...                                                ...
# 89120       I agree                     I am a developer by profession
# 89122       I agree  I am not primarily a developer, but I write co...
# 89165       I agree                     I am a developer by profession
# 89166       I agree                     I am a developer by profession
# 89168       I agree                     I am a developer by profession
#
#                         Age                              Employment  \
# ResponseId
# ...

# %%
len(df.loc[filt])
# Responses from India
# Out:
# 5625

# %%
df.loc[filt]["LanguageHaveWorkedWith"].value_counts().head(50)
# Out:
# LanguageHaveWorkedWith
# HTML/CSS;JavaScript;TypeScript                                       172
# HTML/CSS;JavaScript                                                  108
# Python                                                               105
# Java                                                                  81
# JavaScript                                                            77
# HTML/CSS;JavaScript;PHP;SQL                                           71
# JavaScript;TypeScript                                                 58
# HTML/CSS;JavaScript;Python                                            53
# HTML/CSS;JavaScript;PHP                                               50
# Python;SQL                                                            48
# C#                                                                    44
# JavaScript;Python                                                     40
# HTML/CSS;JavaScript;Python;TypeScript                                 37
# ...

# %%
country_goup["LanguageHaveWorkedWith"].value_counts()
# Out:
# Country      LanguageHaveWorkedWith
# Afghanistan  HTML/CSS;JavaScript;PHP;SQL    2
#              Python;SQL                     2
#              Ada                            1
#              Ada;C                          1
#              Ada;Clojure;Elixir             1
#                                            ..
# Zimbabwe     Java;Kotlin;SQL                1
#              Java;PHP                       1
#              JavaScript                     1
#              Kotlin;Python                  1
#              Rust                           1
# Name: count, Length: 58810, dtype: int64

# %%
country_goup["ConvertedCompYearly"].median().loc["India"]
# Out:
# 19023.0

# %%
country_goup["ConvertedCompYearly"].agg(["median", "mean"]).loc[["India", "United States of America"]]
# Out:
#                             median           mean
# Country
# India                      19023.0   27346.822805
# United States of America  150000.0  170783.961199
