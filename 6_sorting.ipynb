# %%
import pandas as pd

# %%
people = {
    "first": ["Al", "Bhosdu", "Babblu", "Anda"], 
    "last": ["Singh", "Lullu", "Lullu", "Lullu"],
    "email": ["as@gmal.com", "bl@email.com", "bs@email.com", "alulli@gmail.com"]
}

# %%
sample_df = pd.DataFrame(people)

# %%
sample_df
# Out:
#     first   last             email
# 0      Al  Singh       as@gmal.com
# 1  Bhosdu  Lullu      bl@email.com
# 2  Babblu  Lullu      bs@email.com
# 3    Anda  Lullu  alulli@gmail.com

# %%
sample_df.sort_values(by="last", ascending=False)
# Out:
#     first   last             email
# 0      Al  Singh       as@gmal.com
# 1  Bhosdu  Lullu      bl@email.com
# 2  Babblu  Lullu      bs@email.com
# 3    Anda  Lullu  alulli@gmail.com

# %%
sample_df.sort_values(by=["last", "first"], ascending=False)
# Out:
#     first   last             email
# 0      Al  Singh       as@gmal.com
# 1  Bhosdu  Lullu      bl@email.com
# 2  Babblu  Lullu      bs@email.com
# 3    Anda  Lullu  alulli@gmail.com

# %%
sample_df.sort_values(by=["last", "first"], ascending=[False, True], inplace=True)

# %%
sample_df
# Out:
#     first   last             email
# 0      Al  Singh       as@gmal.com
# 3    Anda  Lullu  alulli@gmail.com
# 2  Babblu  Lullu      bs@email.com
# 1  Bhosdu  Lullu      bl@email.com

# %%
sample_df.sort_index()
# Out:
#     first   last             email
# 0      Al  Singh       as@gmal.com
# 1  Bhosdu  Lullu      bl@email.com
# 2  Babblu  Lullu      bs@email.com
# 3    Anda  Lullu  alulli@gmail.com

# %%
sample_df["last"].sort_values()
# Out:
# 3    Lullu
# 2    Lullu
# 1    Lullu
# 0    Singh
# Name: last, dtype: object

# %%
df = pd.read_csv("data/survey_results_public.csv", index_col="ResponseId")
schema_df = pd.read_csv("data/survey_results_schema.csv", index_col="qname")

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head()
# Out:
#                Q120                      MainBranch              Age  \
# ResponseId
# 1           I agree                   None of these  18-24 years old
# 2           I agree  I am a developer by profession  25-34 years old
# 3           I agree  I am a developer by profession  45-54 years old
# 4           I agree  I am a developer by profession  25-34 years old
# 5           I agree  I am a developer by profession  25-34 years old
#
#                                                    Employment  \
# ResponseId
# 1                                                         NaN
# 2                                         Employed, full-time
# 3                                         Employed, full-time
# 4                                         Employed, full-time
# 5           Employed, full-time;Independent contractor, fr...
#
#                                       RemoteWork  \
# ResponseId
# 1                                            NaN
# 2                                         Remote
# 3           Hybrid (some remote, some in-person)
# 4           Hybrid (some remote, some in-person)
# 5                                         Remote
#
#                                              CodingActivities  \
# ResponseId
# 1                                                         NaN
# 2           Hobby;Contribute to open-source projects;Boots...
# 3           Hobby;Professional development or self-paced l...
# 4                                                       Hobby
# 5           Hobby;Contribute to open-source projects;Profe...
#
#                                                  EdLevel  \
# ResponseId
# 1                                                    NaN
# 2           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 4           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 5           Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                                     LearnCode  \
# ResponseId
# 1                                                         NaN
# 2           Books / Physical media;Colleague;Friend or fam...
# 3           Books / Physical media;Colleague;On the job tr...
# 4           Colleague;Friend or family member;Other online...
# 5           Books / Physical media;Online Courses or Certi...
#
#                                               LearnCodeOnline  \
# ResponseId
# 1                                                         NaN
# 2           Formal documentation provided by the owner of ...
# 3           Formal documentation provided by the owner of ...
# 4           Formal documentation provided by the owner of ...
# 5           Formal documentation provided by the owner of ...
#
#             LearnCodeCoursesCert YearsCode YearsCodePro  \
# ResponseId
# 1                            NaN       NaN          NaN
# 2                          Other        18            9
# 3                            NaN        27           23
# 4                            NaN        12            7
# 5           Other;Codecademy;edX         6            4
#
#                                          DevType                   OrgSize  \
# ResponseId
# 1                                            NaN                       NaN
# 2           Senior Executive (C-Suite, VP, etc.)          2 to 9 employees
# 3                            Developer, back-end  5,000 to 9,999 employees
# 4                           Developer, front-end      100 to 499 employees
# 5                          Developer, full-stack        20 to 99 employees
#
#                            PurchaseInfluence      TechList  \
# ResponseId
# 1                                        NaN           NaN
# 2           I have a great deal of influence   Investigate
# 3                      I have some influence  Given a list
# 4                      I have some influence   Investigate
# 5                      I have some influence   Investigate
#
#                                                    BuyNewTool  \
# ResponseId
# 1                                                         NaN
# 2           Start a free trial;Ask developers I know/work ...
# 3           Start a free trial;Ask developers I know/work ...
# 4           Start a free trial;Ask developers I know/work ...
# 5           Start a free trial;Ask developers I know/work ...
#
#                              Country                   Currency  CompTotal  \
# ResponseId
# 1                                NaN                        NaN        NaN
# 2           United States of America  USD\tUnited States dollar   285000.0
# 3           United States of America  USD\tUnited States dollar   250000.0
# 4           United States of America  USD\tUnited States dollar   156000.0
# 5                        Philippines       PHP\tPhilippine peso  1320000.0
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                                  HTML/CSS;JavaScript;Python
# 3                                  Bash/Shell (all shells);Go
# 4           Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 5                              HTML/CSS;JavaScript;TypeScript
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Bash/Shell (all shells);C#;Dart;Elixir;GDScrip...
# 3                                          Haskell;OCaml;Rust
# 4           Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 5                  HTML/CSS;JavaScript;Python;Rust;TypeScript
#
#                                DatabaseHaveWorkedWith  \
# ResponseId
# 1                                                 NaN
# 2                                            Supabase
# 3                                                 NaN
# 4                                    PostgreSQL;Redis
# 5           BigQuery;Elasticsearch;MongoDB;PostgreSQL
#
#                                      DatabaseWantToWorkWith  \
# ResponseId
# 1                                                       NaN
# 2                       Firebase Realtime Database;Supabase
# 3                                                       NaN
# 4                                          PostgreSQL;Redis
# 5           Elasticsearch;MongoDB;PostgreSQL;Redis;Supabase
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2                    Amazon Web Services (AWS);Netlify;Vercel
# 3           Amazon Web Services (AWS);Google Cloud;OpenSta...
# 4                                           Cloudflare;Heroku
# 5           Amazon Web Services (AWS);Firebase;Heroku;Netl...
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                                       Fly.io;Netlify;Render
# 3                                                         NaN
# 4                                           Cloudflare;Heroku
# 5           Amazon Web Services (AWS);Cloudflare;Digital O...
#
#                                   WebframeHaveWorkedWith  \
# ResponseId
# 1                                                    NaN
# 2                             Next.js;React;Remix;Vue.js
# 3                                                    NaN
# 4           Node.js;React;Ruby on Rails;Vue.js;WordPress
# 5            Express;Gatsby;NestJS;Next.js;Node.js;React
#
#                                        WebframeWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2                        Deno;Elm;Nuxt.js;React;Svelte;Vue.js
# 3                                                         NaN
# 4                                Node.js;Ruby on Rails;Vue.js
# 5           Express;NestJS;Next.js;Node.js;React;Remix;Vue.js
#
#                  MiscTechHaveWorkedWith  \
# ResponseId
# 1                                   NaN
# 2           Electron;React Native;Tauri
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
#
#                                    MiscTechWantToWorkWith  \
# ResponseId
# 1                                                     NaN
# 2           Capacitor;Electron;Tauri;Uno Platform;Xamarin
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
#
#                                 ToolsTechHaveWorkedWith  \
# ResponseId
# 1                                                   NaN
# 2           Docker;Kubernetes;npm;Pip;Vite;Webpack;Yarn
# 3                      Cargo;Docker;Kubernetes;Make;Nix
# 4                        Homebrew;npm;Vite;Webpack;Yarn
# 5                               Docker;npm;Webpack;Yarn
#
#                                       ToolsTechWantToWorkWith  \
# ResponseId
# 1                                                         NaN
# 2           Godot;npm;pnpm;Unity 3D;Unreal Engine;Vite;Web...
# 3                                        Cargo;Kubernetes;Nix
# 4                                           Homebrew;npm;Vite
# 5                                             Docker;npm;Yarn
#
#                              NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 1                                                     NaN
# 2                                  Vim;Visual Studio Code
# 3                                             Emacs;Helix
# 4           IntelliJ IDEA;Vim;Visual Studio Code;WebStorm
# 5                                  Vim;Visual Studio Code
#
#            NEWCollabToolsWantToWorkWith  \
# ResponseId
# 1                                   NaN
# 2                Vim;Visual Studio Code
# 3                           Emacs;Helix
# 4            IntelliJ IDEA;Vim;WebStorm
# 5                Vim;Visual Studio Code
#
#                                             OpSysPersonal use  \
# ResponseId
# 1                                                         NaN
# 2           iOS;iPadOS;MacOS;Windows;Windows Subsystem for...
# 3                                     MacOS;Other Linux-based
# 4                                            iOS;iPadOS;MacOS
# 5                                     Other (Please Specify):
#
#                                       OpSysProfessional use  \
# ResponseId
# 1                                                       NaN
# 2           MacOS;Windows;Windows Subsystem for Linux (WSL)
# 3                                   MacOS;Other Linux-based
# 4                                          iOS;iPadOS;MacOS
# 5                                   Other (Please Specify):
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2           Asana;Basecamp;GitHub Discussions;Jira;Linear;...
# 3                      Markdown File;Stack Overflow for Teams
# 4                                                        Jira
# 5                                      Confluence;Jira;Notion
#
#                      OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 1                                               NaN
# 2           GitHub Discussions;Linear;Notion;Trello
# 3                                     Markdown File
# 4                                              Jira
# 5                            Confluence;Jira;Notion
#
#                                 OfficeStackSyncHaveWorkedWith  \
# ResponseId
# 1                                                         NaN
# 2           Cisco Webex Teams;Discord;Google Chat;Google M...
# 3                                  Microsoft Teams;Slack;Zoom
# 4              Discord;Google Meet;Microsoft Teams;Slack;Zoom
# 5                              Discord;Google Meet;Slack;Zoom
#
#              OfficeStackSyncWantToWorkWith AISearchHaveWorkedWith  \
# ResponseId
# 1                                      NaN                    NaN
# 2                Discord;Signal;Slack;Zoom                ChatGPT
# 3                               Slack;Zoom                    NaN
# 4           Discord;Google Meet;Slack;Zoom                    NaN
# 5           Discord;Google Meet;Slack;Zoom                ChatGPT
#
#            AISearchWantToWorkWith AIDevHaveWorkedWith AIDevWantToWorkWith  \
# ResponseId
# 1                             NaN                 NaN                 NaN
# 2                ChatGPT;Neeva AI      GitHub Copilot      GitHub Copilot
# 3                             NaN                 NaN                 NaN
# 4                             NaN                 NaN                 NaN
# 5                         ChatGPT                 NaN                 NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 1                                                         NaN
# 2                               Stack Overflow;Stack Exchange
# 3           Stack Overflow;Stack Exchange;Stack Overflow f...
# 4                               Stack Overflow;Stack Exchange
# 5                               Stack Overflow;Stack Exchange
#
#                                 SOVisitFreq SOAccount  \
# ResponseId
# 1                                       NaN       NaN
# 2                     Daily or almost daily       Yes
# 3           A few times per month or weekly       Yes
# 4                      A few times per week       Yes
# 5                      A few times per week        No
#
#                                      SOPartFreq           SOComm  \
# ResponseId
# 1                                           NaN              NaN
# 2               A few times per month or weekly  Yes, definitely
# 3           Less than once per month or monthly          Neutral
# 4           Less than once per month or monthly   No, not really
# 5                                           NaN          Neutral
#
#                                                          SOAI  \
# ResponseId
# 1                                                         NaN
# 2           I don't think it's super necessary, but I thin...
# 3                                                         NaN
# 4                     I'm wearing of Stack Overflow using AI.
# 5           Using AI to suggest better answer to my questi...
#
#                            AISelect          AISent  \
# ResponseId
# 1                               NaN             NaN
# 2                               Yes     Indifferent
# 3           No, and I don't plan to             NaN
# 4           No, and I don't plan to             NaN
# 5                               Yes  Very favorable
#
#                                                         AIAcc  \
# ResponseId
# 1                                                         NaN
# 2                                      Other (please explain)
# 3                                                         NaN
# 4                                                         NaN
# 5           Increase productivity;Greater efficiency;Speed...
#
#                         AIBen  \
# ResponseId
# 1                         NaN
# 2           Somewhat distrust
# 3                         NaN
# 4                         NaN
# 5              Somewhat trust
#
#                                     AIToolInterested in Using  \
# ResponseId
# 1                                                         NaN
# 2           Learning about a codebase;Writing code;Debuggi...
# 3                                                         NaN
# 4                                                         NaN
# 5           Project planning;Testing code;Committing and r...
#
#                                         AIToolCurrently Using  \
# ResponseId
# 1                                                         NaN
# 2                  Writing code;Committing and reviewing code
# 3                                                         NaN
# 4                                                         NaN
# 5           Learning about a codebase;Writing code;Documen...
#
#            AIToolNot interested in Using AINextVery different  \
# ResponseId
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  NaN
# 4                                    NaN                  NaN
# 5                                    NaN                  NaN
#
#            AINextNeither different nor similar AINextSomewhat similar  \
# ResponseId
# 1                                          NaN                    NaN
# 2                                          NaN                    NaN
# 3                                          NaN                    NaN
# 4                                          NaN                    NaN
# 5                                          NaN                    NaN
#
#            AINextVery similar AINextSomewhat different TBranch  \
# ResponseId
# 1                         NaN                      NaN     NaN
# 2                         NaN                      NaN     Yes
# 3                         NaN                      NaN     Yes
# 4                         NaN                      NaN     Yes
# 5                         NaN                      NaN     Yes
#
#                             ICorPM  WorkExp     Knowledge_1  \
# ResponseId
# 1                              NaN      NaN             NaN
# 2                   People manager     10.0  Strongly agree
# 3           Individual contributor     23.0  Strongly agree
# 4           Individual contributor      7.0  Strongly agree
# 5           Individual contributor      6.0           Agree
#
#                            Knowledge_2     Knowledge_3     Knowledge_4  \
# ResponseId
# 1                                  NaN             NaN             NaN
# 2                                Agree  Strongly agree           Agree
# 3           Neither agree nor disagree           Agree           Agree
# 4                    Strongly disagree  Strongly agree  Strongly agree
# 5                       Strongly agree           Agree           Agree
#
#                            Knowledge_5                 Knowledge_6  \
# ResponseId
# 1                                  NaN                         NaN
# 2                                Agree                       Agree
# 3                                Agree                       Agree
# 4                                Agree  Neither agree nor disagree
# 5           Neither agree nor disagree                       Agree
#
#                Knowledge_7     Knowledge_8        Frequency_1  \
# ResponseId
# 1                      NaN             NaN                NaN
# 2                    Agree  Strongly agree   1-2 times a week
# 3                    Agree           Agree  6-10 times a week
# 4                    Agree           Agree   1-2 times a week
# 5           Strongly agree           Agree   1-2 times a week
#
#                   Frequency_2       Frequency_3         TimeSearching  \
# ResponseId
# 1                         NaN               NaN                   NaN
# 2            10+ times a week             Never   15-30 minutes a day
# 3           6-10 times a week  3-5 times a week   30-60 minutes a day
# 4            10+ times a week  1-2 times a week   15-30 minutes a day
# 5            1-2 times a week  3-5 times a week  60-120 minutes a day
#
#                   TimeAnswering  \
# ResponseId
# 1                           NaN
# 2           15-30 minutes a day
# 3           30-60 minutes a day
# 4           30-60 minutes a day
# 5           30-60 minutes a day
#
#                                              ProfessionalTech  \
# ResponseId
# 1                                                         NaN
# 2           DevOps function;Microservices;Automated testin...
# 3           DevOps function;Microservices;Automated testin...
# 4           Automated testing;Continuous integration (CI) ...
# 5           Microservices;Automated testing;Observability ...
#
#                                                      Industry  \
# ResponseId
# 1                                                         NaN
# 2           Information Services, IT, Software Development...
# 3           Information Services, IT, Software Development...
# 4                                                         NaN
# 5                                                       Other
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 1                             NaN                         NaN
# 2           Appropriate in length                        Easy
# 3           Appropriate in length                        Easy
# 4           Appropriate in length                        Easy
# 5           Appropriate in length  Neither easy nor difficult
#
#             ConvertedCompYearly
# ResponseId
# 1                           NaN
# 2                      285000.0
# 3                      250000.0
# 4                      156000.0
# 5                       23456.0

# %%
# sort by country
df.sort_values(by=["Country","CompTotal"], ascending=[True, False], inplace=True)

# %%
df[["Country", "CompTotal", "Currency"]].head(50)
# Out:
#                 Country    CompTotal  \
# ResponseId
# 88348       Afghanistan  932464379.0
# 1335        Afghanistan     210000.0
# 57362       Afghanistan     200000.0
# 17873       Afghanistan     100000.0
# 36049       Afghanistan      80000.0
# 53322       Afghanistan      69420.0
# 86039       Afghanistan      68000.0
# 41679       Afghanistan      56666.0
# 39427       Afghanistan       4200.0
# 37956       Afghanistan       3600.0
# 2642        Afghanistan        123.0
# 61076       Afghanistan          1.0
# 67794       Afghanistan          0.0
# 59006       Afghanistan          0.0
# 21498       Afghanistan          NaN
# 65293       Afghanistan          NaN
# 33928       Afghanistan          NaN
# 77723       Afghanistan          NaN
# 10377       Afghanistan          NaN
# 83821       Afghanistan          NaN
# 73714       Afghanistan          NaN
# 61453       Afghanistan          NaN
# 21673       Afghanistan          NaN
# 55302       Afghanistan          NaN
# 62550       Afghanistan          NaN
# 84341       Afghanistan          NaN
# 47692       Afghanistan          NaN
# 2301        Afghanistan          NaN
# 51789       Afghanistan          NaN
# 76064       Afghanistan          NaN
# 65337       Afghanistan          NaN
# 82385       Afghanistan          NaN
# 15959       Afghanistan          NaN
# 14420       Afghanistan          NaN
# 53883       Afghanistan          NaN
# 65505       Afghanistan          NaN
# 49208       Afghanistan          NaN
# 46137       Afghanistan          NaN
# 60946       Afghanistan          NaN
# 29006       Afghanistan          NaN
# 20378       Afghanistan          NaN
# 61080       Afghanistan          NaN
# 26532       Afghanistan          NaN
# 31397       Afghanistan          NaN
# 75452       Afghanistan          NaN
# 39319       Afghanistan          NaN
# 57687       Afghanistan          NaN
# 23095       Afghanistan          NaN
# 27885       Afghanistan          NaN
# 55524       Afghanistan          NaN
#
#                                                 Currency
# ResponseId
# 88348                                  ALL\tAlbanian lek
# 1335                                 AFN\tAfghan afghani
# 57362                                AFN\tAfghan afghani
# 17873                                AFN\tAfghan afghani
# 36049                                AFN\tAfghan afghani
# 53322                                AFN\tAfghan afghani
# 86039                          USD\tUnited States dollar
# 41679                                AFN\tAfghan afghani
# 39427                                AFN\tAfghan afghani
# 37956                                AFN\tAfghan afghani
# 2642                     AED United Arab Emirates dirham
# 61076                                DOP\tDominican peso
# 67794       BAM\tBosnia and Herzegovina convertible mark
# 59006                              AZN\tAzerbaijan manat
# 21498                                 ZMW Zambian kwacha
# 65293                    AED United Arab Emirates dirham
# 33928                    AED United Arab Emirates dirham
# 77723                                                NaN
# 10377                                                NaN
# 83821                                AFN\tAfghan afghani
# 73714                                  INR\tIndian rupee
# 61453                    AED United Arab Emirates dirham
# 21673                          USD\tUnited States dollar
# 55302                    AED United Arab Emirates dirham
# 62550                                 AMD\tArmenian dram
# 84341                                                NaN
# 47692                                AFN\tAfghan afghani
# 2301                                                 NaN
# 51789                                  INR\tIndian rupee
# 76064                                                NaN
# 65337                                AFN\tAfghan afghani
# 82385                                                NaN
# 15959                                 AWG\tAruban florin
# 14420                                BHD\tBahraini dinar
# 53883                                                NaN
# 65505                                                NaN
# 49208                                                NaN
# 46137                                AFN\tAfghan afghani
# 60946                    AED United Arab Emirates dirham
# 29006                                                NaN
# 20378                                                NaN
# 61080                                                NaN
# 26532                                                NaN
# 31397                                 AMD\tArmenian dram
# 75452                                                NaN
# 39319                                                NaN
# 57687                                AFN\tAfghan afghani
# 23095                                                NaN
# 27885                    AED United Arab Emirates dirham
# 55524                                AFN\tAfghan afghani

# %%
df["CompTotal"].nlargest(10)
# Out:
# ResponseId
# 56323    5.000000e+46
# 18464    1.000000e+21
# 43557    1.000000e+16
# 49554    1.000000e+16
# 35780    1.000000e+15
# 15440    4.567887e+12
# 33079    1.000000e+11
# 19680    2.239672e+10
# 56854    1.980000e+10
# 9176     1.840199e+10
# Name: CompTotal, dtype: float64

# %%
df.loc[56323]
# Out:
# Q120                                                                             I agree
# MainBranch                                                I am a developer by profession
# Age                                                                      25-34 years old
# Employment                                                           Employed, full-time
# RemoteWork                                                                     In-person
# CodingActivities                       Hobby;Contribute to open-source projects;Boots...
# EdLevel                                   Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# LearnCode                                                        Other (please specify):
# LearnCodeOnline                                                                      NaN
# LearnCodeCoursesCert                                                                 NaN
# YearsCode                                                             More than 50 years
# YearsCodePro                                                          More than 50 years
# DevType                                                                       Blockchain
# OrgSize                                                         10,000 or more employees
# PurchaseInfluence                                                  I have some influence
# TechList                                                                     Investigate
# BuyNewTool                             Start a free trial;Ask developers I know/work ...
# Country                                                                          Bahamas
# Currency                                                 AED United Arab Emirates dirham
# CompTotal                              49999999999999992051087350427974655758076739584.0
# LanguageHaveWorkedWith                                                               Ada
# LanguageWantToWorkWith                                                               NaN
# DatabaseHaveWorkedWith                                                               NaN
# DatabaseWantToWorkWith                                                               NaN
# PlatformHaveWorkedWith                                                               NaN
# PlatformWantToWorkWith                                                               NaN
# WebframeHaveWorkedWith                                                               NaN
# WebframeWantToWorkWith                                                               NaN
# MiscTechHaveWorkedWith                                                               NaN
# MiscTechWantToWorkWith                                                               NaN
# ToolsTechHaveWorkedWith                                                              NaN
# ToolsTechWantToWorkWith                                                              NaN
# NEWCollabToolsHaveWorkedWith                                                         NaN
# NEWCollabToolsWantToWorkWith                                                         NaN
# OpSysPersonal use                                                                    NaN
# OpSysProfessional use                                                                NaN
# OfficeStackAsyncHaveWorkedWith                                                       NaN
# OfficeStackAsyncWantToWorkWith                                                       NaN
# OfficeStackSyncHaveWorkedWith                                                        NaN
# OfficeStackSyncWantToWorkWith                                                        NaN
# AISearchHaveWorkedWith                                                               NaN
# AISearchWantToWorkWith                                                               NaN
# AIDevHaveWorkedWith                                                                  NaN
# AIDevWantToWorkWith                                                                  NaN
# NEWSOSites                             I have never visited Stack Overflow or the Sta...
# SOVisitFreq                                                                          NaN
# SOAccount                                                        Not sure/can't remember
# SOPartFreq                                                                           NaN
# SOComm                                                                    No, not at all
# SOAI                                                                                 SEX
# AISelect                                                         No, and I don't plan to
# AISent                                                                               NaN
# AIAcc                                                                                NaN
# AIBen                                                                                NaN
# AIToolInterested in Using                                                            NaN
# AIToolCurrently Using                                                                NaN
# AIToolNot interested in Using                                                        NaN
# AINextVery different                                                                 NaN
# AINextNeither different nor similar                                                  NaN
# AINextSomewhat similar                                                               NaN
# AINextVery similar                                                                   NaN
# AINextSomewhat different                                                             NaN
# TBranch                                                                               No
# ICorPM                                                                               NaN
# WorkExp                                                                              NaN
# Knowledge_1                                                                          NaN
# Knowledge_2                                                                          NaN
# Knowledge_3                                                                          NaN
# Knowledge_4                                                                          NaN
# Knowledge_5                                                                          NaN
# Knowledge_6                                                                          NaN
# Knowledge_7                                                                          NaN
# Knowledge_8                                                                          NaN
# Frequency_1                                                                          NaN
# Frequency_2                                                                          NaN
# Frequency_3                                                                          NaN
# TimeSearching                                                                        NaN
# TimeAnswering                                                                        NaN
# ProfessionalTech                                                                     NaN
# Industry                                                                             NaN
# SurveyLength                                                                    Too long
# SurveyEase                                                                     Difficult
# ConvertedCompYearly                                                                  NaN
# Name: 56323, dtype: object

# %%
df.nlargest(10, "CompTotal")
# Out:
#                Q120                                         MainBranch  \
# ResponseId
# 56323       I agree                     I am a developer by profession
# 18464       I agree                     I am a developer by profession
# 43557       I agree                     I am a developer by profession
# 49554       I agree  I am not primarily a developer, but I write co...
# 35780       I agree                     I am a developer by profession
# 15440       I agree                     I am a developer by profession
# 33079       I agree                     I am a developer by profession
# 19680       I agree                     I am a developer by profession
# 56854       I agree  I am not primarily a developer, but I write co...
# 9176        I agree                     I am a developer by profession
#
#                         Age  \
# ResponseId
# 56323       25-34 years old
# 18464       25-34 years old
# 43557       18-24 years old
# 49554       25-34 years old
# 35780       25-34 years old
# 15440       25-34 years old
# 33079       25-34 years old
# 19680       25-34 years old
# 56854       18-24 years old
# 9176        25-34 years old
#
#                                                    Employment RemoteWork  \
# ResponseId
# 56323                                     Employed, full-time  In-person
# 18464                                     Employed, full-time  In-person
# 43557                                     Employed, full-time     Remote
# 49554                                     Employed, full-time  In-person
# 35780                                     I prefer not to say        NaN
# 15440                                     Employed, full-time  In-person
# 33079       Independent contractor, freelancer, or self-em...     Remote
# 19680                                     Employed, part-time     Remote
# 56854       Employed, full-time;Independent contractor, fr...     Remote
# 9176                                      Employed, full-time     Remote
#
#                                              CodingActivities  \
# ResponseId
# 56323       Hobby;Contribute to open-source projects;Boots...
# 18464                            I don’t code outside of work
# 43557       Hobby;Contribute to open-source projects;Boots...
# 49554                            I don’t code outside of work
# 35780                                                     NaN
# 15440                                 School or academic work
# 33079                                 Freelance/contract work
# 19680       Professional development or self-paced learnin...
# 56854       Hobby;Contribute to open-source projects;Boots...
# 9176                                                    Hobby
#
#                                                     EdLevel  \
# ResponseId
# 56323        Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 18464          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 43557          Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 49554        Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 35780                                        Something else
# 15440                   Associate degree (A.A., A.S., etc.)
# 33079       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 19680        Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# 56854       Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 9176                              Primary/elementary school
#
#                                                     LearnCode  \
# ResponseId
# 56323                                 Other (please specify):
# 18464       Books / Physical media;Colleague;Friend or fam...
# 43557       Books / Physical media;Online Courses or Certi...
# 49554       Books / Physical media;Colleague;On the job tr...
# 35780       Books / Physical media;Colleague;Friend or fam...
# 15440                                 Friend or family member
# 33079       Other online resources (e.g., videos, blogs, f...
# 19680                                 Other (please specify):
# 56854       Books / Physical media;Online Courses or Certi...
# 9176                                                Colleague
#
#                                               LearnCodeOnline  \
# ResponseId
# 56323                                                     NaN
# 18464                                                     NaN
# 43557       Formal documentation provided by the owner of ...
# 49554       Formal documentation provided by the owner of ...
# 35780       Formal documentation provided by the owner of ...
# 15440                                                     NaN
# 33079       Formal documentation provided by the owner of ...
# 19680                                                     NaN
# 56854       Formal documentation provided by the owner of ...
# 9176                                                      NaN
#
#                                      LearnCodeCoursesCert           YearsCode  \
# ResponseId
# 56323                                                 NaN  More than 50 years
# 18464                                                 NaN                  11
# 43557                                         Pluralsight                   8
# 49554                                                 NaN                  22
# 35780       Codecademy;Udemy;Pluralsight;Coursera;Udacity                  10
# 15440                                                 NaN                   4
# 33079                                                 NaN                  11
# 19680                                                 NaN                   9
# 56854                      Other;edX;Pluralsight;Coursera                  12
# 9176                                                  NaN                 NaN
#
#                   YearsCodePro                                        DevType  \
# ResponseId
# 56323       More than 50 years                                     Blockchain
# 18464                        8                            Developer, back-end
# 43557                        4  Developer, desktop or enterprise applications
# 49554                        5                    Research & Development role
# 35780                        7                                            NaN
# 15440                        2                       Data or business analyst
# 33079                        8                          Developer, full-stack
# 19680                        3                           Developer Experience
# 56854                        7                          Developer, QA or test
# 9176                       NaN                            Academic researcher
#
#                                                       OrgSize  \
# ResponseId
# 56323                                10,000 or more employees
# 18464                                      20 to 99 employees
# 43557                                    500 to 999 employees
# 49554                                1,000 to 4,999 employees
# 35780                                      20 to 99 employees
# 15440                                      20 to 99 employees
# 33079                                        2 to 9 employees
# 19680       Just me - I am a freelancer, sole proprietor, ...
# 56854       Just me - I am a freelancer, sole proprietor, ...
# 9176        Just me - I am a freelancer, sole proprietor, ...
#
#                            PurchaseInfluence      TechList  \
# ResponseId
# 56323                  I have some influence   Investigate
# 18464       I have a great deal of influence   Investigate
# 43557          I have little or no influence           NaN
# 49554                  I have some influence   Investigate
# 35780       I have a great deal of influence   Investigate
# 15440       I have a great deal of influence         Other
# 33079       I have a great deal of influence  Given a list
# 19680          I have little or no influence           NaN
# 56854                  I have some influence   Investigate
# 9176           I have little or no influence           NaN
#
#                                                    BuyNewTool  \
# ResponseId
# 56323       Start a free trial;Ask developers I know/work ...
# 18464       Start a free trial;Ask developers I know/work ...
# 43557       Start a free trial;Ask developers I know/work ...
# 49554       Start a free trial;Ask developers I know/work ...
# 35780       Ask developers I know/work with;Visit develope...
# 15440       Read ratings or reviews on third party sites l...
# 33079       Start a free trial;Ask developers I know/work ...
# 19680                                 Other (please specify):
# 56854       Ask developers I know/work with;Visit develope...
# 9176                                       Start a free trial
#
#                                  Country                         Currency  \
# ResponseId
# 56323                            Bahamas  AED United Arab Emirates dirham
# 18464       Iran, Islamic Republic of...                IRR\tIranian rial
# 43557                            Romania                RON\tRomanian leu
# 49554           United States of America        USD\tUnited States dollar
# 35780                             Canada             CAD\tCanadian dollar
# 15440                           Pakistan             KES\tKenyan shilling
# 33079       Iran, Islamic Republic of...                IRR\tIranian rial
# 19680                               Mali      XOF\tWest African CFA franc
# 56854       Iran, Islamic Republic of...                IRR\tIranian rial
# 9176                          Bangladesh            BDT\tBangladeshi taka
#
#                CompTotal                             LanguageHaveWorkedWith  \
# ResponseId
# 56323       5.000000e+46                                                Ada
# 18464       1.000000e+21                     Bash/Shell (all shells);Python
# 43557       1.000000e+16  Assembly;Bash/Shell (all shells);C;C#;C++;F#;J...
# 49554       1.000000e+16  Bash/Shell (all shells);C;C++;Fortran;Julia;MA...
# 35780       1.000000e+15  Assembly;Bash/Shell (all shells);C#;C++;Cobol;...
# 15440       4.567887e+12                                               Apex
# 33079       1.000000e+11              HTML/CSS;JavaScript;Kotlin;PHP;Python
# 19680       2.239672e+10                                                Ada
# 56854       1.980000e+10  Bash/Shell (all shells);Go;HTML/CSS;JavaScript...
# 9176        1.840199e+10                                                Ada
#
#                                        LanguageWantToWorkWith  \
# ResponseId
# 56323                                                     NaN
# 18464            Bash/Shell (all shells);Go;JavaScript;Python
# 43557       Assembly;Bash/Shell (all shells);C;C#;C++;F#;J...
# 49554       Bash/Shell (all shells);C;C++;Fortran;Julia;MA...
# 35780                                 HTML/CSS;SQL;TypeScript
# 15440                                                     Ada
# 33079              Dart;HTML/CSS;JavaScript;Kotlin;PHP;Python
# 19680                                                     Ada
# 56854       Bash/Shell (all shells);Go;HTML/CSS;Python;Rus...
# 9176                                                      NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                        PostgreSQL;Redis
# 43557       BigQuery;Cosmos DB;Elasticsearch;MariaDB;Micro...
# 49554                                                     NaN
# 35780       Cloud Firestore;Elasticsearch;MariaDB;Microsof...
# 15440                                                BigQuery
# 33079                                            MySQL;SQLite
# 19680                                                BigQuery
# 56854                   MariaDB;MySQL;PostgreSQL;Redis;SQLite
# 9176                                                 BigQuery
#
#                                DatabaseWantToWorkWith  \
# ResponseId
# 56323                                             NaN
# 18464          Elasticsearch;MongoDB;PostgreSQL;Redis
# 43557                                             NaN
# 49554                                             NaN
# 35780                        MariaDB;MySQL;PostgreSQL
# 15440                                             NaN
# 33079                                    MySQL;SQLite
# 19680                                        BigQuery
# 56854       Clickhouse;MariaDB;MySQL;PostgreSQL;Redis
# 9176                                              NaN
#
#                                        PlatformHaveWorkedWith  \
# ResponseId
# 56323                                                     NaN
# 18464                               Amazon Web Services (AWS)
# 43557        Amazon Web Services (AWS);Microsoft Azure;VMware
# 49554                                                     NaN
# 35780       Amazon Web Services (AWS);Cloudflare;Digital O...
# 15440       Amazon Web Services (AWS);Cloudflare;Colocatio...
# 33079                                                     NaN
# 19680                               Amazon Web Services (AWS)
# 56854       Amazon Web Services (AWS);Cloudflare;Digital O...
# 9176                                Amazon Web Services (AWS)
#
#                                        PlatformWantToWorkWith  \
# ResponseId
# 56323                                                     NaN
# 18464                  Amazon Web Services (AWS);Google Cloud
# 43557                                  Microsoft Azure;VMware
# 49554                                                     NaN
# 35780                                                     NaN
# 15440       Managed Hosting;Oracle Cloud Infrastructure (OCI)
# 33079                                                     NaN
# 19680                               Amazon Web Services (AWS)
# 56854             Cloudflare;Hetzner;Microsoft Azure;Scaleway
# 9176                                                      NaN
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                                 FastAPI
# 43557                                    ASP.NET;ASP.NET CORE
# 49554                                                     NaN
# 35780       Angular;AngularJS;ASP.NET;ASP.NET CORE;Deno;Ex...
# 15440       Angular;AngularJS;ASP.NET;ASP.NET CORE;Blazor;...
# 33079            Express;jQuery;Laravel;Next.js;Node.js;React
# 19680                                                 Angular
# 56854              Express;Flask;Next.js;Node.js;React;Vue.js
# 9176                                                      NaN
#
#                                   WebframeWantToWorkWith  \
# ResponseId
# 56323                                                NaN
# 18464                                            FastAPI
# 43557                                                NaN
# 49554                                                NaN
# 35780                                     Angular;NestJS
# 15440                                                NaN
# 33079       Express;jQuery;Laravel;Next.js;Node.js;React
# 19680                                            Angular
# 56854                 FastAPI;Flask;Next.js;React;Svelte
# 9176                                                 NaN
#
#                          MiscTechHaveWorkedWith  \
# ResponseId
# 56323                                       NaN
# 18464                                       NaN
# 43557       .NET (5+) ;GTK;MFC;Opencv;OpenGL;Qt
# 49554                              NumPy;Pandas
# 35780                                  Electron
# 15440                                       NaN
# 33079                                        Qt
# 19680                                .NET (5+)
# 56854                                       NaN
# 9176                                        NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                                     NaN
# 43557                                GTK;MFC;Opencv;OpenGL;Qt
# 49554       CUDA;GTK;NumPy;Pandas;Qt;Scikit-Learn;TensorFl...
# 35780                                                     NaN
# 15440                                                     NaN
# 33079                                                      Qt
# 19680                                              .NET (5+)
# 56854                                                     NaN
# 9176                                                      NaN
#
#                                       ToolsTechHaveWorkedWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                         Composer;Docker
# 43557       Ant;APT;Boost.Test;CMake;cppunit;Dagger;Docker...
# 49554                        CMake;Docker;Make;MSVC;Ninja;Pip
# 35780       Chocolatey;CMake;Composer;Docker;Gradle;npm;We...
# 15440                                                  Dagger
# 33079                                                     NaN
# 19680                                                 Ansible
# 56854                 Ansible;APT;Docker;npm;Pip;Webpack;Yarn
# 9176                                                      NaN
#
#                                       ToolsTechWantToWorkWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                         Composer;Docker
# 43557       Boost.Test;CMake;cppunit;GNU GCC;LLVM's Clang;...
# 49554                             CMake;LLVM's Clang;Make;Pip
# 35780                                              Docker;npm
# 15440                                                  Dagger
# 33079                                                     NaN
# 19680                                                 Ansible
# 56854                    Ansible;APT;Docker;Make;Nix;Pip;Yarn
# 9176                                                      NaN
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                     IPython;PyCharm;Vim
# 43557       Atom;Code::Blocks;Kate;Nano;Notepad++;Qt Creat...
# 49554                 Notepad++;Spyder;Vim;Visual Studio Code
# 35780       Android Studio;Atom;Eclipse;Goland;IntelliJ ID...
# 15440                                          Android Studio
# 33079       Android Studio;Atom;Notepad++;PhpStorm;Qt Crea...
# 19680                                          Android Studio
# 56854                Vim;Visual Studio Code;VSCodium;WebStorm
# 9176                                           Android Studio
#
#                                  NEWCollabToolsWantToWorkWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                     IPython;PyCharm;Vim
# 43557                           Kate;Qt Creator;Visual Studio
# 49554                 Notepad++;Spyder;Vim;Visual Studio Code
# 35780                                      Visual Studio Code
# 15440                                                     NaN
# 33079       Android Studio;Atom;Notepad++;PhpStorm;Qt Crea...
# 19680                                          Android Studio
# 56854                         Vim;Visual Studio Code;VSCodium
# 9176                                           Android Studio
#
#                                             OpSysPersonal use  \
# ResponseId
# 56323                                                     NaN
# 18464                                                  Ubuntu
# 43557                                   Cygwin;Ubuntu;Windows
# 49554                                          Debian;Windows
# 35780       Android;Ubuntu;Windows;Windows Subsystem for L...
# 15440                                                     AIX
# 33079                                                 Windows
# 19680                                                     AIX
# 56854             Android;Arch;Debian;MacOS;Other Linux-based
# 9176                                  Other (Please Specify):
#
#                                         OpSysProfessional use  \
# ResponseId
# 56323                                                     NaN
# 18464                                                  Ubuntu
# 43557                                                  Ubuntu
# 49554                                         Red Hat;Windows
# 35780       Android;Red Hat;Ubuntu;Windows;Windows Subsyst...
# 15440                                                     NaN
# 33079                                                 Windows
# 19680                                                     AIX
# 56854                      Debian;iOS;MacOS;Other Linux-based
# 9176                                  Other (Please Specify):
#
#                                OfficeStackAsyncHaveWorkedWith  \
# ResponseId
# 56323                                                     NaN
# 18464                                             Jira;Trello
# 43557                        GitHub Discussions;Markdown File
# 49554                                   Markdown File;Redmine
# 35780       Azure Devops;Confluence;Jira;Markdown File;Trello
# 15440                                         Adobe Workfront
# 33079                                                     NaN
# 19680                                         Adobe Workfront
# 56854       Clickup;Confluence;Jira;Markdown File;Miro;Mon...
# 9176                                                      NaN
#
#              OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 56323                                   NaN
# 18464                           Jira;Trello
# 43557                    GitHub Discussions
# 49554                 Markdown File;Redmine
# 35780                                   NaN
# 15440                                   NaN
# 33079                                   NaN
# 19680                       Adobe Workfront
# 56854       Markdown File;Miro;Notion;Wikis
# 9176                                    NaN
#
#                                 OfficeStackSyncHaveWorkedWith  \
# ResponseId
# 56323                                                     NaN
# 18464       Discord;Google Meet;Jitsi;Skype;Slack;Telegram...
# 43557                               IRC;Microsoft Teams;Skype
# 49554                                         Microsoft Teams
# 35780       Cisco Webex Teams;Discord;Google Chat;Google M...
# 15440                                       Cisco Webex Teams
# 33079                                                     NaN
# 19680                                       Cisco Webex Teams
# 56854                            Discord;Google Meet;Telegram
# 9176        Coolfire Core;Discord;Google Chat;Google Meet;...
#
#                                 OfficeStackSyncWantToWorkWith  \
# ResponseId
# 56323                                                     NaN
# 18464             Discord;Google Meet;Skype;Telegram;Whatsapp
# 43557                                                     NaN
# 49554                                         Microsoft Teams
# 35780                                                 Discord
# 15440                                                     NaN
# 33079                                                     NaN
# 19680                                       Cisco Webex Teams
# 56854                                    Google Meet;Telegram
# 9176        Coolfire Core;Discord;Google Chat;Google Meet;...
#
#            AISearchHaveWorkedWith               AISearchWantToWorkWith  \
# ResponseId
# 56323                         NaN                                  NaN
# 18464                         NaN                                  NaN
# 43557                         NaN                                  NaN
# 49554                WolframAlpha  ChatGPT;Google Bard AI;WolframAlpha
# 35780                     ChatGPT                                  NaN
# 15440                        Andi                                  NaN
# 33079                         NaN                                  NaN
# 19680                        Andi                                 Andi
# 56854             ChatGPT;You.com                                  NaN
# 9176                          NaN                                  NaN
#
#            AIDevHaveWorkedWith AIDevWantToWorkWith  \
# ResponseId
# 56323                      NaN                 NaN
# 18464                      NaN                 NaN
# 43557                      NaN                 NaN
# 49554                      NaN                 NaN
# 35780           GitHub Copilot                 NaN
# 15440                      NaN                 NaN
# 33079                      NaN                 NaN
# 19680               Adrenaline          Adrenaline
# 56854                      NaN                 NaN
# 9176                       NaN                 NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 56323       I have never visited Stack Overflow or the Sta...
# 18464                           Stack Overflow;Stack Exchange
# 43557       Stack Overflow;Stack Exchange;Stack Overflow f...
# 49554                           Stack Overflow;Stack Exchange
# 35780                           Stack Overflow;Stack Exchange
# 15440                           Collectives on Stack Overflow
# 33079       Stack Overflow;Stack Exchange;Stack Overflow f...
# 19680                           Collectives on Stack Overflow
# 56854       Stack Overflow;Stack Exchange;Collectives on S...
# 9176                            Collectives on Stack Overflow
#
#                                     SOVisitFreq                SOAccount  \
# ResponseId
# 56323                                       NaN  Not sure/can't remember
# 18464                    Multiple times per day                      Yes
# 43557       Less than once per month or monthly                      Yes
# 49554                    Multiple times per day                      Yes
# 35780           A few times per month or weekly                      Yes
# 15440                     Daily or almost daily                      Yes
# 33079                    Multiple times per day                      Yes
# 19680       Less than once per month or monthly                      Yes
# 56854                     Daily or almost daily                      Yes
# 9176        Less than once per month or monthly                      Yes
#
#                                                    SOPartFreq  \
# ResponseId
# 56323                                                     NaN
# 18464                                    A few times per week
# 43557                     Less than once per month or monthly
# 49554                     Less than once per month or monthly
# 35780                     Less than once per month or monthly
# 15440       I have never participated in Q&A on Stack Over...
# 33079                                  Multiple times per day
# 19680       I have never participated in Q&A on Stack Over...
# 56854                                   Daily or almost daily
# 9176        I have never participated in Q&A on Stack Over...
#
#                      SOComm  \
# ResponseId
# 56323        No, not at all
# 18464         Yes, somewhat
# 43557               Neutral
# 49554        No, not really
# 35780               Neutral
# 15440               Neutral
# 33079       Yes, definitely
# 19680               Neutral
# 56854         Yes, somewhat
# 9176         No, not at all
#
#                                                          SOAI  \
# ResponseId
# 56323                                                     SEX
# 18464                                                     NaN
# 43557                                                   don't
# 49554       It would be most helpful if the AI could delet...
# 35780                                                    none
# 15440                                                 Gvmhmko
# 33079                                                     NaN
# 19680                                           Profossionnal
# 56854       It's not mature enough yet, Maybe it can be us...
# 9176                                                      NaN
#
#                            AISelect          AISent  \
# ResponseId
# 56323       No, and I don't plan to             NaN
# 18464       No, and I don't plan to             NaN
# 43557       No, and I don't plan to             NaN
# 49554       No, and I don't plan to             NaN
# 35780       No, and I don't plan to             NaN
# 15440        No, but I plan to soon     Indifferent
# 33079                           Yes  Very favorable
# 19680                           Yes  Very favorable
# 56854        No, but I plan to soon     Indifferent
# 9176                            Yes  Very favorable
#
#                                               AIAcc  \
# ResponseId
# 56323                                           NaN
# 18464                                           NaN
# 43557                                           NaN
# 49554                                           NaN
# 35780                                           NaN
# 15440                                           NaN
# 33079       Increase productivity;Speed up learning
# 19680                        Other (please explain)
# 56854                                           NaN
# 9176                          Increase productivity
#
#                                  AIBen  \
# ResponseId
# 56323                              NaN
# 18464                              NaN
# 43557                              NaN
# 49554                              NaN
# 35780                              NaN
# 15440       Neither trust nor distrust
# 33079                   Somewhat trust
# 19680                     Highly trust
# 56854                  Highly distrust
# 9176                      Highly trust
#
#                                     AIToolInterested in Using  \
# ResponseId
# 56323                                                     NaN
# 18464                                                     NaN
# 43557                                                     NaN
# 49554                                                     NaN
# 35780                                                     NaN
# 15440                                                     NaN
# 33079       Learning about a codebase;Project planning;Wri...
# 19680                                                     NaN
# 56854                                                     NaN
# 9176                                                      NaN
#
#                                         AIToolCurrently Using  \
# ResponseId
# 56323                                                     NaN
# 18464                                                     NaN
# 43557                                                     NaN
# 49554                                                     NaN
# 35780                                                     NaN
# 15440                                                     NaN
# 33079       Learning about a codebase;Project planning;Wri...
# 19680                                                     NaN
# 56854                                                     NaN
# 9176                                Learning about a codebase
#
#            AIToolNot interested in Using  \
# ResponseId
# 56323                                NaN
# 18464                                NaN
# 43557                                NaN
# 49554                                NaN
# 35780                                NaN
# 15440                                NaN
# 33079                                NaN
# 19680                                NaN
# 56854                                NaN
# 9176                                 NaN
#
#                                          AINextVery different  \
# ResponseId
# 56323                                                     NaN
# 18464                                                     NaN
# 43557                                                     NaN
# 49554                                                     NaN
# 35780                                                     NaN
# 15440                                                     NaN
# 33079       Learning about a codebase;Project planning;Wri...
# 19680                                                     NaN
# 56854                                                     NaN
# 9176                                Learning about a codebase
#
#            AINextNeither different nor similar AINextSomewhat similar  \
# ResponseId
# 56323                                      NaN                    NaN
# 18464                                      NaN                    NaN
# 43557                                      NaN                    NaN
# 49554                                      NaN                    NaN
# 35780                                      NaN                    NaN
# 15440                                      NaN                    NaN
# 33079                                      NaN                    NaN
# 19680                                      NaN                    NaN
# 56854                                      NaN                    NaN
# 9176                                       NaN                    NaN
#
#            AINextVery similar AINextSomewhat different TBranch  \
# ResponseId
# 56323                     NaN                      NaN      No
# 18464                     NaN                      NaN     Yes
# 43557                     NaN                      NaN      No
# 49554                     NaN                      NaN     Yes
# 35780                     NaN                      NaN      No
# 15440                     NaN                      NaN     Yes
# 33079                     NaN                      NaN      No
# 19680                     NaN                      NaN     NaN
# 56854                     NaN                      NaN     Yes
# 9176                      NaN                      NaN     Yes
#
#                             ICorPM  WorkExp                 Knowledge_1  \
# ResponseId
# 56323                          NaN      NaN                         NaN
# 18464               People manager     11.0              Strongly agree
# 43557                          NaN      NaN                         NaN
# 49554       Individual contributor     11.0                       Agree
# 35780                          NaN      NaN                         NaN
# 15440       Individual contributor     16.0  Neither agree nor disagree
# 33079                          NaN      NaN                         NaN
# 19680                          NaN      NaN                         NaN
# 56854       Individual contributor      7.0                    Disagree
# 9176                People manager     20.0           Strongly disagree
#
#                            Knowledge_2                 Knowledge_3  \
# ResponseId
# 56323                              NaN                         NaN
# 18464       Neither agree nor disagree                       Agree
# 43557                              NaN                         NaN
# 49554                            Agree                       Agree
# 35780                              NaN                         NaN
# 15440                Strongly disagree  Neither agree nor disagree
# 33079                              NaN                         NaN
# 19680                              NaN                         NaN
# 56854                         Disagree                    Disagree
# 9176                               NaN                         NaN
#
#                            Knowledge_4     Knowledge_5     Knowledge_6  \
# ResponseId
# 56323                              NaN             NaN             NaN
# 18464                   Strongly agree  Strongly agree  Strongly agree
# 43557                              NaN             NaN             NaN
# 49554       Neither agree nor disagree           Agree           Agree
# 35780                              NaN             NaN             NaN
# 15440                              NaN             NaN             NaN
# 33079                              NaN             NaN             NaN
# 19680                              NaN             NaN             NaN
# 56854       Neither agree nor disagree           Agree        Disagree
# 9176                               NaN             NaN             NaN
#
#                            Knowledge_7     Knowledge_8       Frequency_1  \
# ResponseId
# 56323                              NaN             NaN               NaN
# 18464       Neither agree nor disagree  Strongly agree             Never
# 43557                              NaN             NaN               NaN
# 49554       Neither agree nor disagree           Agree  1-2 times a week
# 35780                              NaN             NaN               NaN
# 15440                              NaN             NaN               NaN
# 33079                              NaN             NaN               NaN
# 19680                              NaN             NaN               NaN
# 56854                            Agree           Agree  1-2 times a week
# 9176                               NaN             NaN             Never
#
#                   Frequency_2        Frequency_3               TimeSearching  \
# ResponseId
# 56323                     NaN                NaN                         NaN
# 18464       6-10 times a week                NaN         30-60 minutes a day
# 43557                     NaN                NaN                         NaN
# 49554        3-5 times a week   1-2 times a week         30-60 minutes a day
# 35780                     NaN                NaN                         NaN
# 15440                     NaN  6-10 times a week         30-60 minutes a day
# 33079                     NaN                NaN                         NaN
# 19680                     NaN                NaN                         NaN
# 56854        1-2 times a week              Never        60-120 minutes a day
# 9176                    Never                NaN  Less than 15 minutes a day
#
#                          TimeAnswering  \
# ResponseId
# 56323                              NaN
# 18464              30-60 minutes a day
# 43557                              NaN
# 49554              30-60 minutes a day
# 35780                              NaN
# 15440           Over 120 minutes a day
# 33079                              NaN
# 19680                              NaN
# 56854              15-30 minutes a day
# 9176        Less than 15 minutes a day
#
#                                              ProfessionalTech  \
# ResponseId
# 56323                                                     NaN
# 18464       Microservices;Continuous integration (CI) and ...
# 43557                                                     NaN
# 49554       DevOps function;Automated testing;Continuous i...
# 35780                                                     NaN
# 15440       Continuous integration (CI) and (more often) c...
# 33079                                                     NaN
# 19680                                                     NaN
# 56854       Automated testing;Continuous integration (CI) ...
# 9176                                   Innersource initiative
#
#                                                      Industry  \
# ResponseId
# 56323                                                     NaN
# 18464                                                     NaN
# 43557                                                     NaN
# 49554       Information Services, IT, Software Development...
# 35780                                                     NaN
# 15440                                                     NaN
# 33079                                                     NaN
# 19680                                                     NaN
# 56854       Information Services, IT, Software Development...
# 9176                                                      NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 56323                    Too long                   Difficult
# 18464       Appropriate in length                        Easy
# 43557                    Too long  Neither easy nor difficult
# 49554       Appropriate in length                        Easy
# 35780                    Too long                        Easy
# 15440       Appropriate in length                         NaN
# 33079       Appropriate in length                        Easy
# 19680                   Too short                        Easy
# 56854       Appropriate in length  Neither easy nor difficult
# 9176                    Too short                         NaN
#
#             ConvertedCompYearly
# ResponseId
# 56323                       NaN
# 18464                       NaN
# 43557                       NaN
# 49554                       NaN
# 35780                       NaN
# 15440                       NaN
# 33079                 2362249.0
# 19680                36573181.0
# 56854                  467725.0
# 9176                        NaN

# %%
df
# Out:
#                Q120                      MainBranch                Age  \
# ResponseId
# 88348       I agree  I am a developer by profession    25-34 years old
# 1335        I agree  I am a developer by profession    18-24 years old
# 57362       I agree  I am a developer by profession    18-24 years old
# 17873       I agree  I am a developer by profession    25-34 years old
# 36049       I agree  I am a developer by profession    25-34 years old
# ...             ...                             ...                ...
# 88821       I agree                   None of these    35-44 years old
# 88829       I agree                   None of these    25-34 years old
# 88831       I agree                   None of these    18-24 years old
# 89029       I agree                   None of these    45-54 years old
# 89160       I agree                   None of these  Prefer not to say
#
#                      Employment                            RemoteWork  \
# ResponseId
# 88348       Employed, full-time  Hybrid (some remote, some in-person)
# 1335        Employed, full-time  Hybrid (some remote, some in-person)
# 57362       Employed, full-time  Hybrid (some remote, some in-person)
# 17873       Employed, part-time  Hybrid (some remote, some in-person)
# 36049       Employed, full-time                             In-person
# ...                         ...                                   ...
# 88821                       NaN                                   NaN
# 88829                       NaN                                   NaN
# 88831                       NaN                                   NaN
# 89029                       NaN                                   NaN
# 89160                       NaN                                   NaN
#
#                                              CodingActivities  \
# ResponseId
# 88348                          Hobby;Bootstrapping a business
# 1335        Professional development or self-paced learnin...
# 57362                                 Freelance/contract work
# 17873       Hobby;Professional development or self-paced l...
# 36049                          Hobby;Bootstrapping a business
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                                                       EdLevel  \
# ResponseId
# 88348            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 1335             Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 57362       Some college/university study without earning ...
# 17873            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 36049            Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                                                     LearnCode  \
# ResponseId
# 88348       Books / Physical media;School (i.e., Universit...
# 1335        Online Courses or Certification;Other online r...
# 57362       Books / Physical media;On the job training;Oth...
# 17873       Colleague;Online Courses or Certification;On t...
# 36049       Colleague;Online Courses or Certification;Othe...
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                                               LearnCodeOnline  \
# ResponseId
# 88348                                                     NaN
# 1335        Blogs with tips and tricks;Recorded coding ses...
# 57362       Formal documentation provided by the owner of ...
# 17873                                                     NaN
# 36049       Formal documentation provided by the owner of ...
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#            LearnCodeCoursesCert YearsCode YearsCodePro                DevType  \
# ResponseId
# 88348                       NaN         8            3             Blockchain
# 1335             Udemy;Coursera         3            1  Developer, full-stack
# 57362                       NaN         4            3  Developer, full-stack
# 17873                       NaN         3            1   Developer, front-end
# 36049                Codecademy         5            2  Developer, full-stack
# ...                         ...       ...          ...                    ...
# 88821                       NaN       NaN          NaN                    NaN
# 88829                       NaN       NaN          NaN                    NaN
# 88831                       NaN       NaN          NaN                    NaN
# 89029                       NaN       NaN          NaN                    NaN
# 89160                       NaN       NaN          NaN                    NaN
#
#                        OrgSize                 PurchaseInfluence  \
# ResponseId
# 88348         2 to 9 employees             I have some influence
# 1335        10 to 19 employees  I have a great deal of influence
# 57362       20 to 99 employees             I have some influence
# 17873       20 to 99 employees             I have some influence
# 36049       10 to 19 employees  I have a great deal of influence
# ...                        ...                               ...
# 88821                      NaN                               NaN
# 88829                      NaN                               NaN
# 88831                      NaN                               NaN
# 89029                      NaN                               NaN
# 89160                      NaN                               NaN
#
#                 TechList                                         BuyNewTool  \
# ResponseId
# 88348        Investigate                    Ask developers I know/work with
# 1335         Investigate  Ask developers I know/work with;Visit develope...
# 57362        Investigate  Ask developers I know/work with;Read ratings o...
# 17873                NaN                                                NaN
# 36049       Given a list        Start a free trial;Ask a generative AI tool
# ...                  ...                                                ...
# 88821                NaN                                                NaN
# 88829                NaN                                                NaN
# 88831                NaN                                                NaN
# 89029                NaN                                                NaN
# 89160                NaN                                                NaN
#
#                 Country             Currency    CompTotal  \
# ResponseId
# 88348       Afghanistan    ALL\tAlbanian lek  932464379.0
# 1335        Afghanistan  AFN\tAfghan afghani     210000.0
# 57362       Afghanistan  AFN\tAfghan afghani     200000.0
# 17873       Afghanistan  AFN\tAfghan afghani     100000.0
# 36049       Afghanistan  AFN\tAfghan afghani      80000.0
# ...                 ...                  ...          ...
# 88821               NaN                  NaN          NaN
# 88829               NaN                  NaN          NaN
# 88831               NaN                  NaN          NaN
# 89029               NaN                  NaN          NaN
# 89160               NaN                  NaN          NaN
#
#                                        LanguageHaveWorkedWith  \
# ResponseId
# 88348                                                   Cobol
# 1335                                           C;C++;Java;PHP
# 57362       C++;HTML/CSS;JavaScript;PowerShell;Python;Type...
# 17873       C;C#;C++;Dart;HTML/CSS;Java;JavaScript;Kotlin;...
# 36049       HTML/CSS;JavaScript;PHP;Python;SQL;VBA;Visual ...
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                                    LanguageWantToWorkWith  \
# ResponseId
# 88348                                  JavaScript;VBA;Zig
# 1335                  Go;JavaScript;Python;SQL;TypeScript
# 57362               HTML/CSS;JavaScript;PowerShell;Python
# 17873          Go;HTML/CSS;JavaScript;Rust;SQL;TypeScript
# 36049       HTML/CSS;JavaScript;Lua;Python;SQL;TypeScript
# ...                                                   ...
# 88821                                                 NaN
# 88829                                                 NaN
# 88831                                                 NaN
# 89029                                                 NaN
# 89160                                                 NaN
#
#                                        DatabaseHaveWorkedWith  \
# ResponseId
# 88348                            Cockroachdb;Microsoft Access
# 1335                                                      NaN
# 57362                                              PostgreSQL
# 17873       Firebase Realtime Database;MongoDB;MySQL;Postg...
# 36049                                    MariaDB;MySQL;SQLite
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                                        DatabaseWantToWorkWith  \
# ResponseId
# 88348                                                     NaN
# 1335                                                      NaN
# 57362                                              PostgreSQL
# 17873       Firebase Realtime Database;MongoDB;MySQL;Postg...
# 36049                   MariaDB;MySQL;PostgreSQL;Redis;SQLite
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                PlatformHaveWorkedWith  \
# ResponseId
# 88348       Amazon Web Services (AWS)
# 1335                  Firebase;Heroku
# 57362                         Netlify
# 17873         Firebase;Netlify;Vercel
# 36049             Google Cloud;Heroku
# ...                               ...
# 88821                             NaN
# 88829                             NaN
# 88831                             NaN
# 89029                             NaN
# 89160                             NaN
#
#                                    PlatformWantToWorkWith  \
# ResponseId
# 88348                                                 NaN
# 1335        Amazon Web Services (AWS);Google Cloud;Vercel
# 57362                                             Netlify
# 17873            Amazon Web Services (AWS);Netlify;Vercel
# 36049                                        Google Cloud
# ...                                                   ...
# 88821                                                 NaN
# 88829                                                 NaN
# 88831                                                 NaN
# 89029                                                 NaN
# 89160                                                 NaN
#
#                                        WebframeHaveWorkedWith  \
# ResponseId
# 88348                                           Ruby on Rails
# 1335                                                      NaN
# 57362                          Django;Node.js;React;WordPress
# 17873       CodeIgniter;Django;Express;Next.js;Node.js;Nux...
# 36049       Django;jQuery;Laravel;Next.js;Node.js;React;Vu...
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                                   WebframeWantToWorkWith  \
# ResponseId
# 88348                                             jQuery
# 1335                                                 NaN
# 57362                     Django;Node.js;React;WordPress
# 17873       Express;Next.js;Node.js;Nuxt.js;React;Svelte
# 36049               Django;Express;Next.js;Node.js;React
# ...                                                  ...
# 88821                                                NaN
# 88829                                                NaN
# 88831                                                NaN
# 89029                                                NaN
# 89160                                                NaN
#
#                     MiscTechHaveWorkedWith  \
# ResponseId
# 88348                                 CUDA
# 1335                              Electron
# 57362                         React Native
# 17873                              Flutter
# 36049       Electron;Flutter;Qt;TensorFlow
# ...                                    ...
# 88821                                  NaN
# 88829                                  NaN
# 88831                                  NaN
# 89029                                  NaN
# 89160                                  NaN
#
#                                        MiscTechWantToWorkWith  \
# ResponseId
# 88348                                            React Native
# 1335              NumPy;Opencv;Pandas;React Native;TensorFlow
# 57362                                            React Native
# 17873                                                     NaN
# 36049       Electron;NumPy;Opencv;Qt;TensorFlow;Torch/PyTorch
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                       ToolsTechHaveWorkedWith  \
# ResponseId
# 88348                      Kubernetes;Webpack
# 1335                                      NaN
# 57362                     Docker;npm;Pip;Vite
# 17873                                  Wasmer
# 36049       CMake;Make;npm;Pacman;Pip;Webpack
# ...                                       ...
# 88821                                     NaN
# 88829                                     NaN
# 88831                                     NaN
# 89029                                     NaN
# 89160                                     NaN
#
#                       ToolsTechWantToWorkWith  \
# ResponseId
# 88348                                    Vite
# 1335                                      NaN
# 57362                     Docker;npm;Pip;Vite
# 17873                                  Wasmer
# 36049       CMake;Make;npm;Pacman;Pip;Webpack
# ...                                       ...
# 88821                                     NaN
# 88829                                     NaN
# 88831                                     NaN
# 89029                                     NaN
# 89160                                     NaN
#
#                                  NEWCollabToolsHaveWorkedWith  \
# ResponseId
# 88348                                                   Emacs
# 1335                                                      NaN
# 57362                        Visual Studio;Visual Studio Code
# 17873       Android Studio;IntelliJ IDEA;Jupyter Notebook/...
# 36049                                 Neovim;Sublime Text;Vim
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                               NEWCollabToolsWantToWorkWith OpSysPersonal use  \
# ResponseId
# 88348                                               Neovim              Arch
# 1335                                                   NaN               NaN
# 57362                     Visual Studio;Visual Studio Code    Ubuntu;Windows
# 17873       Jupyter Notebook/JupyterLab;Visual Studio Code      MacOS;Ubuntu
# 36049                              Neovim;Sublime Text;Vim              Arch
# ...                                                    ...               ...
# 88821                                                  NaN               NaN
# 88829                                                  NaN               NaN
# 88831                                                  NaN               NaN
# 89029                                                  NaN               NaN
# 89160                                                  NaN               NaN
#
#                                 OpSysProfessional use  \
# ResponseId
# 88348                                         Windows
# 1335        Windows;Windows Subsystem for Linux (WSL)
# 57362                                  Ubuntu;Windows
# 17873                                    MacOS;Ubuntu
# 36049                                            Arch
# ...                                               ...
# 88821                                             NaN
# 88829                                             NaN
# 88831                                             NaN
# 89029                                             NaN
# 89160                                             NaN
#
#            OfficeStackAsyncHaveWorkedWith OfficeStackAsyncWantToWorkWith  \
# ResponseId
# 88348                     Adobe Workfront                            NaN
# 1335                         Asana;Trello                Confluence;Jira
# 57362                                Jira                            NaN
# 17873                                Jira                           Jira
# 36049                              Notion                         Notion
# ...                                   ...                            ...
# 88821                                 NaN                            NaN
# 88829                                 NaN                            NaN
# 88831                                 NaN                            NaN
# 89029                                 NaN                            NaN
# 89160                                 NaN                            NaN
#
#                 OfficeStackSyncHaveWorkedWith OfficeStackSyncWantToWorkWith  \
# ResponseId
# 88348                       Cisco Webex Teams                       Discord
# 1335                                    Slack       Discord;Microsoft Teams
# 57362                                Telegram                      Telegram
# 17873                  Telegram;Whatsapp;Zoom        Telegram;Whatsapp;Zoom
# 36049       Microsoft Teams;Telegram;Whatsapp      Microsoft Teams;Telegram
# ...                                       ...                           ...
# 88821                                     NaN                           NaN
# 88829                                     NaN                           NaN
# 88831                                     NaN                           NaN
# 89029                                     NaN                           NaN
# 89160                                     NaN                           NaN
#
#            AISearchHaveWorkedWith AISearchWantToWorkWith AIDevHaveWorkedWith  \
# ResponseId
# 88348                WolframAlpha           WolframAlpha                 NaN
# 1335                          NaN                    NaN                 NaN
# 57362                         NaN                    NaN                 NaN
# 17873                     ChatGPT                ChatGPT      GitHub Copilot
# 36049                     ChatGPT                ChatGPT                 NaN
# ...                           ...                    ...                 ...
# 88821                         NaN                    NaN                 NaN
# 88829                         NaN                    NaN                 NaN
# 88831                         NaN                    NaN                 NaN
# 89029                         NaN                    NaN                 NaN
# 89160                         NaN                    NaN                 NaN
#
#            AIDevWantToWorkWith  \
# ResponseId
# 88348                      NaN
# 1335                       NaN
# 57362                      NaN
# 17873           GitHub Copilot
# 36049                      NaN
# ...                        ...
# 88821                      NaN
# 88829                      NaN
# 88831                      NaN
# 89029                      NaN
# 89160                      NaN
#
#                                                    NEWSOSites  \
# ResponseId
# 88348       I have never visited Stack Overflow or the Sta...
# 1335                                           Stack Overflow
# 57362                                          Stack Overflow
# 17873                                          Stack Overflow
# 36049                           Stack Overflow;Stack Exchange
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                        SOVisitFreq SOAccount  \
# ResponseId
# 88348                          NaN        No
# 1335                           NaN       Yes
# 57362        Daily or almost daily       Yes
# 17873         A few times per week       Yes
# 36049       Multiple times per day       Yes
# ...                            ...       ...
# 88821                          NaN       NaN
# 88829                          NaN       NaN
# 88831                          NaN       NaN
# 89029                          NaN       NaN
# 89160                          NaN       NaN
#
#                                      SOPartFreq           SOComm  \
# ResponseId
# 88348                                       NaN   No, not at all
# 1335                      Daily or almost daily  Yes, definitely
# 57362       Less than once per month or monthly          Neutral
# 17873                      A few times per week    Yes, somewhat
# 36049           A few times per month or weekly          Neutral
# ...                                         ...              ...
# 88821                                       NaN              NaN
# 88829                                       NaN              NaN
# 88831                                       NaN              NaN
# 89029                                       NaN              NaN
# 89160                                       NaN              NaN
#
#                                                          SOAI  \
# ResponseId
# 88348                                                     NaN
# 1335        I would recommend stack overflow to take benef...
# 57362                                                     NaN
# 17873                                                     NaN
# 36049                   they are somehow good but not prefect
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                           AISelect          AISent               AIAcc  \
# ResponseId
# 88348       No, but I plan to soon     Indifferent                 NaN
# 1335        No, but I plan to soon  Very favorable                 NaN
# 57362       No, but I plan to soon          Unsure                 NaN
# 17873                          Yes       Favorable                 NaN
# 36049                          Yes       Favorable  Greater efficiency
# ...                            ...             ...                 ...
# 88821                          NaN             NaN                 NaN
# 88829                          NaN             NaN                 NaN
# 88831                          NaN             NaN                 NaN
# 89029                          NaN             NaN                 NaN
# 89160                          NaN             NaN                 NaN
#
#                                  AIBen  \
# ResponseId
# 88348                Somewhat distrust
# 1335                    Somewhat trust
# 57362       Neither trust nor distrust
# 17873                              NaN
# 36049                   Somewhat trust
# ...                                ...
# 88821                              NaN
# 88829                              NaN
# 88831                              NaN
# 89029                              NaN
# 89160                              NaN
#
#                                     AIToolInterested in Using  \
# ResponseId
# 88348                                                     NaN
# 1335                                                      NaN
# 57362                                                     NaN
# 17873                                                     NaN
# 36049       Learning about a codebase;Project planning;Wri...
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                                         AIToolCurrently Using  \
# ResponseId
# 88348                                                     NaN
# 1335                                                      NaN
# 57362                                                     NaN
# 17873                                                     NaN
# 36049       Learning about a codebase;Writing code;Documen...
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#            AIToolNot interested in Using AINextVery different  \
# ResponseId
# 88348                                NaN                  NaN
# 1335                                 NaN                  NaN
# 57362                                NaN                  NaN
# 17873                                NaN                  NaN
# 36049                                NaN                  NaN
# ...                                  ...                  ...
# 88821                                NaN                  NaN
# 88829                                NaN                  NaN
# 88831                                NaN                  NaN
# 89029                                NaN                  NaN
# 89160                                NaN                  NaN
#
#            AINextNeither different nor similar AINextSomewhat similar  \
# ResponseId
# 88348                                      NaN                    NaN
# 1335                                       NaN                    NaN
# 57362                                      NaN                    NaN
# 17873                                      NaN                    NaN
# 36049                                      NaN                    NaN
# ...                                        ...                    ...
# 88821                                      NaN                    NaN
# 88829                                      NaN                    NaN
# 88831                                      NaN                    NaN
# 89029                                      NaN                    NaN
# 89160                                      NaN                    NaN
#
#                                            AINextVery similar  \
# ResponseId
# 88348                                                     NaN
# 1335                                                      NaN
# 57362                                                     NaN
# 17873                                                     NaN
# 36049       Learning about a codebase;Writing code;Documen...
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#            AINextSomewhat different TBranch                  ICorPM  WorkExp  \
# ResponseId
# 88348                           NaN      No                     NaN      NaN
# 1335                            NaN      No                     NaN      NaN
# 57362                           NaN     Yes  Individual contributor      4.0
# 17873                           NaN     Yes  Individual contributor      2.0
# 36049                           NaN     Yes  Individual contributor      4.0
# ...                             ...     ...                     ...      ...
# 88821                           NaN     NaN                     NaN      NaN
# 88829                           NaN     NaN                     NaN      NaN
# 88831                           NaN     NaN                     NaN      NaN
# 89029                           NaN     NaN                     NaN      NaN
# 89160                           NaN     NaN                     NaN      NaN
#
#            Knowledge_1                 Knowledge_2 Knowledge_3 Knowledge_4  \
# ResponseId
# 88348              NaN                         NaN         NaN         NaN
# 1335               NaN                         NaN         NaN         NaN
# 57362            Agree  Neither agree nor disagree    Disagree       Agree
# 17873              NaN                         NaN         NaN         NaN
# 36049            Agree                    Disagree    Disagree       Agree
# ...                ...                         ...         ...         ...
# 88821              NaN                         NaN         NaN         NaN
# 88829              NaN                         NaN         NaN         NaN
# 88831              NaN                         NaN         NaN         NaN
# 89029              NaN                         NaN         NaN         NaN
# 89160              NaN                         NaN         NaN         NaN
#
#            Knowledge_5        Knowledge_6                 Knowledge_7  \
# ResponseId
# 88348              NaN                NaN                         NaN
# 1335               NaN                NaN                         NaN
# 57362            Agree  Strongly disagree  Neither agree nor disagree
# 17873              NaN                NaN                         NaN
# 36049            Agree              Agree  Neither agree nor disagree
# ...                ...                ...                         ...
# 88821              NaN                NaN                         NaN
# 88829              NaN                NaN                         NaN
# 88831              NaN                NaN                         NaN
# 89029              NaN                NaN                         NaN
# 89160              NaN                NaN                         NaN
#
#                            Knowledge_8       Frequency_1       Frequency_2  \
# ResponseId
# 88348                              NaN               NaN               NaN
# 1335                               NaN               NaN               NaN
# 57362       Neither agree nor disagree  1-2 times a week  1-2 times a week
# 17873                              NaN               NaN               NaN
# 36049       Neither agree nor disagree  10+ times a week  10+ times a week
# ...                                ...               ...               ...
# 88821                              NaN               NaN               NaN
# 88829                              NaN               NaN               NaN
# 88831                              NaN               NaN               NaN
# 89029                              NaN               NaN               NaN
# 89160                              NaN               NaN               NaN
#
#                   Frequency_3        TimeSearching         TimeAnswering  \
# ResponseId
# 88348                     NaN                  NaN                   NaN
# 1335                      NaN                  NaN                   NaN
# 57362        10+ times a week  30-60 minutes a day   15-30 minutes a day
# 17873                     NaN                  NaN                   NaN
# 36049       6-10 times a week  30-60 minutes a day  60-120 minutes a day
# ...                       ...                  ...                   ...
# 88821                     NaN                  NaN                   NaN
# 88829                     NaN                  NaN                   NaN
# 88831                     NaN                  NaN                   NaN
# 89029                     NaN                  NaN                   NaN
# 89160                     NaN                  NaN                   NaN
#
#                          ProfessionalTech  \
# ResponseId
# 88348                                 NaN
# 1335                                  NaN
# 57362                       None of these
# 17873       DevOps function;Microservices
# 36049                       None of these
# ...                                   ...
# 88821                                 NaN
# 88829                                 NaN
# 88831                                 NaN
# 89029                                 NaN
# 89160                                 NaN
#
#                                                      Industry  \
# ResponseId
# 88348                                                     NaN
# 1335                                                      NaN
# 57362                                                     NaN
# 17873       Information Services, IT, Software Development...
# 36049                                          Legal Services
# ...                                                       ...
# 88821                                                     NaN
# 88829                                                     NaN
# 88831                                                     NaN
# 89029                                                     NaN
# 89160                                                     NaN
#
#                      SurveyLength                  SurveyEase  \
# ResponseId
# 88348                    Too long                        Easy
# 1335        Appropriate in length                        Easy
# 57362       Appropriate in length  Neither easy nor difficult
# 17873                         NaN                         NaN
# 36049       Appropriate in length                        Easy
# ...                           ...                         ...
# 88821                         NaN                         NaN
# 88829                         NaN                         NaN
# 88831                         NaN                         NaN
# 89029                         NaN                         NaN
# 89160                         NaN                         NaN
#
#             ConvertedCompYearly
# ResponseId
# 88348                 9203683.0
# 1335                     2403.0
# 57362                    2288.0
# 17873                    1144.0
# 36049                     915.0
# ...                         ...
# 88821                       NaN
# 88829                       NaN
# 88831                       NaN
# 89029                       NaN
# 89160                       NaN
#
# [89184 rows x 83 columns]
